# %% [markdown]
# # Script for combining multiple multiplayer result files into a single multiplayer file
#
# (This script makes it easier to allow multiple players to compete in a multiplayer Type Through the Bible Game simultaneously on different computers. Here's how they can do so:
#
# 1. After individual players finish their tests, either within a one-player multiplayer game or within the main single-player game, they should transfer their results to a central folder.
# 2. Next, one player should copy or move all *test-result files* (e.g. not *word-result files*) into the MP_Test_Result_Files_To_Combine folder, located within the Files/ directory. That player should then run this script in order to combine those files into a single results file that can then be analyzed like any other multiplayer file.
#
# This file can handle the following input data:
#
# 1. Multiplayer files with just one player
# 3. Multiplayer files with multiple players (which will be handy if two or more players need to share a laptop)
# 4. Single-player files. (I recommend making the number of tests divisible by 10, since that way, players can simply copy their autosave data into the central folder.)
#
# In addition, files *with* and *without* headers are compatible with this script.
#
# This script can also handle cases in which two or more players have the same name, provided that they are not in the same multiplayer file. It will do so by appending a distinct suffix to all but one of these files.
#
# **Important: if a player has not completed all of the tests specified by the first_verse_id and last_verse_id arguments, he/she will be excluded from the combined file!**

# %%
import pandas as pd
pd.set_option('display.max_columns', 1000)
import os
import subprocess

# %% [markdown]
# (For documentation on the following sets of code, see the similar set of code within mp_visualizations.ipynb.)

# %%
notebook_exec = False
try:
    get_ipython()
    notebook_exec = True 
except:
    pass

notebook_exec

if notebook_exec == False:
    # The following code was based on
    # https://docs.python.org/3/howto/argparse.html#argparse-tutorial
    # and # https://docs.python.org/3/library/argparse.html .
    import argparse
    parser = argparse.ArgumentParser()
    parser.add_argument("first_verse_id", type = int)
    parser.add_argument("last_verse_id", type = int)
    args = parser.parse_args()
    first_verse_id = args.first_verse_id
    last_verse_id = args.last_verse_id
    
else: # Update these as needed when running the Jupyter notebook directly
    first_verse_id = 30786
    last_verse_id = 30795

unique_verse_count = last_verse_id - first_verse_id + 1

first_verse_id, last_verse_id, unique_verse_count
# Out:
# (30786, 30795, 10)

# %%
mp_test_result_folder_path = '../Files/MP_Test_Result_Files_To_Combine/'
mp_test_result_files = os.listdir(mp_test_result_folder_path)
mp_test_result_files
# Out:
# ['20250725T131157_mp2playertest_test_results.csv',
#  '20250725T130821_ken3test_test_results.csv',
#  'autosaved_test_results_Ken1.csv',
#  'autosaved_test_results_Ken2.csv',
#  'autosaved_test_results_Ken2_missing_verse.csv']

# %%
mp_test_result_headers = ['Test_Number', 'Within_Session_Test_Number', 
'Unix_Test_Start_Time', 'Local_Test_Start_Time', 'Unix_Test_End_Time', 
'Local_Test_End_Time', 'Verse_ID', 'Verse_Code', 'Verse', 'Characters', 
'WPM', 'Test_Seconds', 'Error_Rate', 'Error_and_Backspace_Rate', 
'Marathon_Mode', 'Player', 'Mode', 'Tag_1', 'Tag_2', 'Tag_3', 'Notes']

# %%
player_count = 1 # This list will help us assign unique initial codes
# to each player's name, thus helping distinguish multiple players
# who happen to have the same name (as long as those duplicate names
# aren't contained in the same source file).

df_result_list = [] # Creating a list of DataFrames, one for each
# file, that will ultimately get converted into a single DataFrame

# Processing each file within mp_test_result_folder_path:
for filename in mp_test_result_files:
    # Reading in the first row of the DataFrame in order to check whether
    # this file contains headers or not:
    df_first_row = pd.read_csv(
        mp_test_result_folder_path + filename,
        header = None, nrows = 1)
# Setting the header parameter to None ensures that the first row of the
# .csv file, whether it contains headers or data, will get treated as
# a row of data (thus making it easier to check what values it contains).
    if df_first_row.iloc[0, 0] == 'Test_Number': # This indicates that 
# the file does contain headers; thus, we should make the 'names' argument
# for our upcoming read_csv call None so that read_csv() will convert
# the first row of the .csv file into the DataFrame's header row.
        names_arg = None
    else: # This indicates that the file does not contain headers. 
        # Therefore, we'll need to pass the headers stored in 
        # mp_test_result_headers to the 'header' argument so that they can 
        # be used as header values.
        names_arg = mp_test_result_headers
    
    
    # Now that we know what headers to use within our read_csv call,
    # we can import the entire dataset:
    
    df = pd.read_csv(mp_test_result_folder_path + filename,
                    names = names_arg)

    # Seeing which players are present in the file:
    player_list = df['Player'].unique()
    
    # Filtering the DataFrame to only include tests that fall within
    # the first_verse_id and last_verse_id bounds defined earlier:

    df.query("Verse_ID >= @first_verse_id & Verse_ID <= @last_verse_id",
            inplace = True)

    # Checking whether each player completed the range of tests
    # that starts at first_verse_id and ends at last_verse_id:
    # (Any player that did not complete all of these tests will be 
    # removed from the combined file.)
    for player in df['Player'].unique():
        if len(df.query("Player == @player")['Verse_ID'].unique()
) != unique_verse_count:
            print(f"{player} within {filename} did not complete all of \
the tests between {first_verse_id} and {last_verse_id}; thus, this player \
will be excluded from the combined dataset.")
            df.query("Player != @player", inplace = True)
               
    
    # Making sure the tests are sorted in chronological order:
    # (We'll use Unix time here to prevent time zone differences from
    # affecting this sort.)
    df = df.sort_values(
        'Unix_Test_Start_Time').reset_index(drop=True).copy()
    

    # Adding numerical prefixes to each player's name in order to help 
    # differentiate between two players who happen to have the same name:
    for player in player_list:
        df['Player'] = df['Player'].replace(
            {player:str(player_count)+'_'+str(player)}).copy()
        player_count += 1
    
    # Replacing existing Tag_1 and Tag_2 values with 
    # a standardized set of values:
    # (This step is necessary because single-player files will likely have 
    # different tag values than multiplayer ones.)
    # As a reminder, tags 1, 2, and 3 normally refer to rounds,
    # tests within rounds, and player-specific test numbers, respectively.
    
    df['Tag_1'] = 1 # We'll treat this multiplayer game as having just one
    # round (which would be the case for any players who completed these
    # tests on their own)
    
    df['Tag_3'] = df.groupby('Player')['WPM'].transform('cumcount') + 1
    
    # Because this game has only one round, tags 2 and 3 will have the 
    # same value.
    
    df['Tag_2'] = df['Tag_3'].copy()
    # Storing the original filename within the 'Notes' field:
    df['Notes'] = filename

    
    df_result_list.append(df)

# Combining all of these results into a single DataFrame:
df_combined = pd.concat([df for df in df_result_list])
# Sorting the tests by chronological order so that we can assign
# accurate Test_Number and Within_Session_Test_Number values:

df_combined = df_combined.sort_values(
    'Unix_Test_Start_Time').reset_index(drop=True).copy()
# We'll treat all of the races as occurring within the same session.
for column in ['Test_Number', 'Within_Session_Test_Number']:
    df_combined[column] = df_combined.index + 1
df_combined
# Out:
# KJB3 within autosaved_test_results_Ken2_missing_verse.csv did not complete all of the tests between 30786 and 30795; thus, this player will be excluded from the combined dataset.
#     Test_Number  Within_Session_Test_Number  Unix_Test_Start_Time  \
# 0             1                           1            1753463005
# 1             2                           2            1753463015
# 2             3                           3            1753463020
# 3             4                           4            1753463029
# 4             5                           5            1753463038
# 5             6                           6            1753463046
# 6             7                           7            1753463051
# 7             8                           8            1753463075
# 8             9                           9            1753463080
# 9            10                          10            1753463087
# 10           11                          11            1753463180
# 11           12                          12            1753463189
# 12           13                          13            1753463193
# 13           14                          14            1753463201
# 14           15                          15            1753463205
# 15           16                          16            1753463212
# 16           17                          17            1753463217
# 17           18                          18            1753463227
# 18           19                          19            1753463235
# 19           20                          20            1753463242
# 20           21                          21            1753463351
# 21           22                          22            1753463364
# 22           23                          23            1753463367
# 23           24                          24            1753463375
# 24           25                          25            1753463379
# 25           26                          26            1753463386
# 26           27                          27            1753463391
# 27           28                          28            1753463400
# 28           29                          29            1753463407
# 29           30                          30            1753463416
# 30           31                          31            1753463729
# 31           32                          32            1753463738
# 32           33                          33            1753463742
# 33           34                          34            1753463753
# 34           35                          35            1753463759
# 35           36                          36            1753463770
# 36           37                          37            1753463778
# 37           38                          38            1753463783
# 38           39                          39            1753463790
# 39           40                          40            1753463795
# 40           41                          41            1753463812
# 41           42                          42            1753463817
# 42           43                          43            1753463826
# 43           44                          44            1753463835
# 44           45                          45            1753463842
# 45           46                          46            1753463851
# 46           47                          47            1753463856
# 47           48                          48            1753463892
# 48           49                          49            1753463900
# 49           50                          50            1753463907
#
#        Local_Test_Start_Time  Unix_Test_End_Time       Local_Test_End_Time  \
# 0   2025-07-25T13:03:25-0400          1753463011  2025-07-25T13:03:31-0400
# 1   2025-07-25T13:03:35-0400          1753463019  2025-07-25T13:03:39-0400
# 2   2025-07-25T13:03:40-0400          1753463028  2025-07-25T13:03:48-0400
# 3   2025-07-25T13:03:49-0400          1753463034  2025-07-25T13:03:54-0400
# 4   2025-07-25T13:03:58-0400          1753463043  2025-07-25T13:04:03-0400
# 5   2025-07-25T13:04:06-0400          1753463049  2025-07-25T13:04:09-0400
# 6   2025-07-25T13:04:11-0400          1753463059  2025-07-25T13:04:19-0400
# 7   2025-07-25T13:04:35-0400          1753463080  2025-07-25T13:04:40-0400
# 8   2025-07-25T13:04:40-0400          1753463086  2025-07-25T13:04:46-0400
# 9   2025-07-25T13:04:47-0400          1753463094  2025-07-25T13:04:54-0400
# 10  2025-07-25T13:06:20-0400          1753463187  2025-07-25T13:06:27-0400
# 11  2025-07-25T13:06:29-0400          1753463192  2025-07-25T13:06:32-0400
# 12  2025-07-25T13:06:33-0400          1753463200  2025-07-25T13:06:40-0400
# 13  2025-07-25T13:06:41-0400          1753463204  2025-07-25T13:06:44-0400
# 14  2025-07-25T13:06:45-0400          1753463211  2025-07-25T13:06:51-0400
# 15  2025-07-25T13:06:52-0400          1753463216  2025-07-25T13:06:56-0400
# 16  2025-07-25T13:06:57-0400          1753463226  2025-07-25T13:07:06-0400
# 17  2025-07-25T13:07:07-0400          1753463232  2025-07-25T13:07:12-0400
# 18  2025-07-25T13:07:15-0400          1753463240  2025-07-25T13:07:20-0400
# 19  2025-07-25T13:07:22-0400          1753463251  2025-07-25T13:07:31-0400
# 20  2025-07-25T13:09:11-0400          1753463359  2025-07-25T13:09:19-0400
# 21  2025-07-25T13:09:24-0400          1753463366  2025-07-25T13:09:26-0400
# 22  2025-07-25T13:09:27-0400          1753463373  2025-07-25T13:09:33-0400
# 23  2025-07-25T13:09:35-0400          1753463378  2025-07-25T13:09:38-0400
# 24  2025-07-25T13:09:39-0400          1753463385  2025-07-25T13:09:45-0400
# 25  2025-07-25T13:09:46-0400          1753463390  2025-07-25T13:09:50-0400
# 26  2025-07-25T13:09:51-0400          1753463399  2025-07-25T13:09:59-0400
# 27  2025-07-25T13:10:00-0400          1753463405  2025-07-25T13:10:05-0400
# 28  2025-07-25T13:10:07-0400          1753463413  2025-07-25T13:10:13-0400
# 29  2025-07-25T13:10:16-0400          1753463424  2025-07-25T13:10:24-0400
# 30  2025-07-25T13:15:29-0400          1753463736  2025-07-25T13:15:36-0400
# 31  2025-07-25T13:15:38-0400          1753463740  2025-07-25T13:15:40-0400
# 32  2025-07-25T13:15:42-0400          1753463751  2025-07-25T13:15:51-0400
# 33  2025-07-25T13:15:53-0400          1753463757  2025-07-25T13:15:57-0400
# 34  2025-07-25T13:15:59-0400          1753463765  2025-07-25T13:16:05-0400
# 35  2025-07-25T13:16:10-0400          1753463776  2025-07-25T13:16:16-0400
# 36  2025-07-25T13:16:18-0400          1753463781  2025-07-25T13:16:21-0400
# 37  2025-07-25T13:16:23-0400          1753463789  2025-07-25T13:16:29-0400
# 38  2025-07-25T13:16:30-0400          1753463794  2025-07-25T13:16:34-0400
# 39  2025-07-25T13:16:35-0400          1753463801  2025-07-25T13:16:41-0400
# 40  2025-07-25T13:16:52-0400          1753463816  2025-07-25T13:16:56-0400
# 41  2025-07-25T13:16:57-0400          1753463825  2025-07-25T13:17:05-0400
# 42  2025-07-25T13:17:06-0400          1753463833  2025-07-25T13:17:13-0400
# 43  2025-07-25T13:17:15-0400          1753463841  2025-07-25T13:17:21-0400
# 44  2025-07-25T13:17:22-0400          1753463849  2025-07-25T13:17:29-0400
# 45  2025-07-25T13:17:31-0400          1753463855  2025-07-25T13:17:35-0400
# 46  2025-07-25T13:17:36-0400          1753463864  2025-07-25T13:17:44-0400
# 47  2025-07-25T13:18:12-0400          1753463899  2025-07-25T13:18:19-0400
# 48  2025-07-25T13:18:20-0400          1753463906  2025-07-25T13:18:26-0400
# 49  2025-07-25T13:18:27-0400          1753463918  2025-07-25T13:18:38-0400
#
#     Verse_ID Verse_Code                                              Verse  \
# 0      30786   John_1:1  In the beginning was the Word, and the Word wa...
# 1      30787   John_1:2                  He was with God in the beginning.
# 2      30788   John_1:3  All things were made through Him, and nothing ...
# 3      30789   John_1:4    Life was in Him, and Life was the light of men.
# 4      30790   John_1:5  And the light shines in the darkness, and the ...
# 5      30791   John_1:6  There was a man sent by God, whose name was John.
# 6      30792   John_1:7  He arrived as a witness to offer testimony abo...
# 7      30793   John_1:8  He was not the Light, but he was to offer test...
# 8      30794   John_1:9  The true Light, which illuminates every man, w...
# 9      30795  John_1:10  He was in the world, and the world was made th...
# 10     30786   John_1:1  In the beginning was the Word, and the Word wa...
# 11     30787   John_1:2                  He was with God in the beginning.
# 12     30788   John_1:3  All things were made through Him, and nothing ...
# 13     30789   John_1:4    Life was in Him, and Life was the light of men.
# 14     30790   John_1:5  And the light shines in the darkness, and the ...
# 15     30791   John_1:6  There was a man sent by God, whose name was John.
# 16     30792   John_1:7  He arrived as a witness to offer testimony abo...
# 17     30793   John_1:8  He was not the Light, but he was to offer test...
# 18     30794   John_1:9  The true Light, which illuminates every man, w...
# 19     30795  John_1:10  He was in the world, and the world was made th...
# 20     30786   John_1:1  In the beginning was the Word, and the Word wa...
# 21     30787   John_1:2                  He was with God in the beginning.
# 22     30788   John_1:3  All things were made through Him, and nothing ...
# 23     30789   John_1:4    Life was in Him, and Life was the light of men.
# 24     30790   John_1:5  And the light shines in the darkness, and the ...
# 25     30791   John_1:6  There was a man sent by God, whose name was John.
# 26     30792   John_1:7  He arrived as a witness to offer testimony abo...
# 27     30793   John_1:8  He was not the Light, but he was to offer test...
# 28     30794   John_1:9  The true Light, which illuminates every man, w...
# 29     30795  John_1:10  He was in the world, and the world was made th...
# 30     30786   John_1:1  In the beginning was the Word, and the Word wa...
# 31     30787   John_1:2                  He was with God in the beginning.
# 32     30788   John_1:3  All things were made through Him, and nothing ...
# 33     30789   John_1:4    Life was in Him, and Life was the light of men.
# 34     30790   John_1:5  And the light shines in the darkness, and the ...
# 35     30786   John_1:1  In the beginning was the Word, and the Word wa...
# 36     30787   John_1:2                  He was with God in the beginning.
# 37     30788   John_1:3  All things were made through Him, and nothing ...
# 38     30789   John_1:4    Life was in Him, and Life was the light of men.
# 39     30790   John_1:5  And the light shines in the darkness, and the ...
# 40     30791   John_1:6  There was a man sent by God, whose name was John.
# 41     30792   John_1:7  He arrived as a witness to offer testimony abo...
# 42     30793   John_1:8  He was not the Light, but he was to offer test...
# 43     30794   John_1:9  The true Light, which illuminates every man, w...
# 44     30795  John_1:10  He was in the world, and the world was made th...
# 45     30791   John_1:6  There was a man sent by God, whose name was John.
# 46     30792   John_1:7  He arrived as a witness to offer testimony abo...
# 47     30793   John_1:8  He was not the Light, but he was to offer test...
# 48     30794   John_1:9  The true Light, which illuminates every man, w...
# 49     30795  John_1:10  He was in the world, and the world was made th...
#
#     Characters         WPM  Test_Seconds  Error_Rate  \
# 0           79  147.108798      6.444210    0.101266
# 1           33  107.419623      3.686477    0.181818
# 2           81  119.750078      8.116905    0.135802
# 3           47  131.118032      4.301468    0.042553
# 4           77  166.496865      5.549654    0.000000
# 5           49  150.672821      3.902495    0.000000
# 6           98  136.909295      8.589629    0.061224
# 7           68  160.121786      5.096121    0.000000
# 8           72  153.049868      5.645219    0.013889
# 9           93  157.508131      7.085349    0.000000
# 10          79  140.578321      6.743572    0.101266
# 11          33  122.570887      3.230783    0.060606
# 12          81  152.249396      6.384262    0.024691
# 13          47  146.563300      3.848167    0.000000
# 14          77  168.399464      5.486953    0.000000
# 15          49  153.137624      3.839683    0.000000
# 16          98  132.598937      8.868849    0.010204
# 17          68  152.416113      5.353765    0.014706
# 18          72  152.168075      5.677932    0.000000
# 19          93  127.988412      8.719539    0.064516
# 20          79  122.685249      7.727090    0.202532
# 21          33  170.097038      2.328083    0.000000
# 22          81  154.018175      6.310943    0.012346
# 23          47  173.174778      3.256825    0.000000
# 24          77  161.302565      5.728365    0.000000
# 25          49  157.343933      3.737036    0.000000
# 26          98  155.501843      7.562611    0.010204
# 27          68  150.643188      5.416773    0.029412
# 28          72  134.975076      6.401182    0.055556
# 29          93  131.090907      8.513176    0.064516
# 30          79  146.134774      6.487162    0.101266
# 31          33  179.484263      2.206322    0.000000
# 32          81  112.096731      8.671083    0.135802
# 33          47  141.941519      3.973467    0.021277
# 34          77  161.129247      5.734527    0.012987
# 35          79  161.842393      5.857551    0.000000
# 36          33  112.499908      3.520003    0.212121
# 37          81  170.405900      5.704028    0.000000
# 38          47  165.140554      3.415273    0.000000
# 39          77  174.967876      5.280969    0.000000
# 40          49  151.589403      3.878899    0.000000
# 41          98  154.573485      7.608032    0.010204
# 42          68  112.726618      7.238752    0.132353
# 43          72  144.364740      5.984841    0.000000
# 44          93  155.964679      7.155466    0.000000
# 45          49  143.042732      4.110660    0.000000
# 46          98  154.444346      7.614393    0.000000
# 47          68  119.277133      6.841211    0.073529
# 48          72  156.458508      5.522231    0.000000
# 49          93  100.564664     11.097337    0.193548
#
#     Error_and_Backspace_Rate  Marathon_Mode  Player Mode  Tag_1  Tag_2  Tag_3  \
# 0                   0.126582              0  4_KJB3   SP      1      1      1
# 1                   0.242424              0  4_KJB3   SP      1      2      2
# 2                   0.172840              0  4_KJB3   SP      1      3      3
# 3                   0.085106              0  4_KJB3   SP      1      4      4
# 4                   0.000000              0  4_KJB3   SP      1      5      5
# 5                   0.000000              0  4_KJB3   SP      1      6      6
# 6                   0.071429              0  4_KJB3   SP      1      7      7
# 7                   0.000000              0  4_KJB3   SP      1      8      8
# 8                   0.027778              0  4_KJB3   SP      1      9      9
# 9                   0.000000              0  4_KJB3   SP      1     10     10
# 10                  0.126582              0  5_KJB3   SP      1      1      1
# 11                  0.121212              0  5_KJB3   SP      1      2      2
# 12                  0.049383              0  5_KJB3   SP      1      3      3
# 13                  0.000000              0  5_KJB3   SP      1      4      4
# 14                  0.000000              0  5_KJB3   SP      1      5      5
# 15                  0.000000              0  5_KJB3   SP      1      6      6
# 16                  0.020408              0  5_KJB3   SP      1      7      7
# 17                  0.029412              0  5_KJB3   SP      1      8      8
# 18                  0.000000              0  5_KJB3   SP      1      9      9
# 19                  0.107527              0  5_KJB3   SP      1     10     10
# 20                  0.265823              0  3_Ken3   MP      1      1      1
# 21                  0.000000              0  3_Ken3   MP      1      2      2
# 22                  0.024691              0  3_Ken3   MP      1      3      3
# 23                  0.000000              0  3_Ken3   MP      1      4      4
# 24                  0.000000              0  3_Ken3   MP      1      5      5
# 25                  0.000000              0  3_Ken3   MP      1      6      6
# 26                  0.020408              0  3_Ken3   MP      1      7      7
# 27                  0.058824              0  3_Ken3   MP      1      8      8
# 28                  0.111111              0  3_Ken3   MP      1      9      9
# 29                  0.096774              0  3_Ken3   MP      1     10     10
# 30                  0.126582              0  1_KJB3   MP      1      1      1
# 31                  0.000000              0  1_KJB3   MP      1      2      2
# 32                  0.185185              0  1_KJB3   MP      1      3      3
# 33                  0.042553              0  1_KJB3   MP      1      4      4
# 34                  0.025974              0  1_KJB3   MP      1      5      5
# 35                  0.000000              0  2_Ken4   MP      1      1      1
# 36                  0.272727              0  2_Ken4   MP      1      2      2
# 37                  0.000000              0  2_Ken4   MP      1      3      3
# 38                  0.000000              0  2_Ken4   MP      1      4      4
# 39                  0.000000              0  2_Ken4   MP      1      5      5
# 40                  0.000000              0  1_KJB3   MP      1      6      6
# 41                  0.020408              0  1_KJB3   MP      1      7      7
# 42                  0.176471              0  1_KJB3   MP      1      8      8
# 43                  0.000000              0  1_KJB3   MP      1      9      9
# 44                  0.000000              0  1_KJB3   MP      1     10     10
# 45                  0.000000              0  2_Ken4   MP      1      6      6
# 46                  0.000000              0  2_Ken4   MP      1      7      7
# 47                  0.147059              0  2_Ken4   MP      1      8      8
# 48                  0.000000              0  2_Ken4   MP      1      9      9
# 49                  0.311828              0  2_Ken4   MP      1     10     10
#
#                                              Notes
# 0                  autosaved_test_results_Ken1.csv
# 1                  autosaved_test_results_Ken1.csv
# 2                  autosaved_test_results_Ken1.csv
# 3                  autosaved_test_results_Ken1.csv
# 4                  autosaved_test_results_Ken1.csv
# 5                  autosaved_test_results_Ken1.csv
# 6                  autosaved_test_results_Ken1.csv
# 7                  autosaved_test_results_Ken1.csv
# 8                  autosaved_test_results_Ken1.csv
# 9                  autosaved_test_results_Ken1.csv
# 10                 autosaved_test_results_Ken2.csv
# 11                 autosaved_test_results_Ken2.csv
# 12                 autosaved_test_results_Ken2.csv
# 13                 autosaved_test_results_Ken2.csv
# 14                 autosaved_test_results_Ken2.csv
# 15                 autosaved_test_results_Ken2.csv
# 16                 autosaved_test_results_Ken2.csv
# 17                 autosaved_test_results_Ken2.csv
# 18                 autosaved_test_results_Ken2.csv
# 19                 autosaved_test_results_Ken2.csv
# 20       20250725T130821_ken3test_test_results.csv
# 21       20250725T130821_ken3test_test_results.csv
# 22       20250725T130821_ken3test_test_results.csv
# 23       20250725T130821_ken3test_test_results.csv
# 24       20250725T130821_ken3test_test_results.csv
# 25       20250725T130821_ken3test_test_results.csv
# 26       20250725T130821_ken3test_test_results.csv
# 27       20250725T130821_ken3test_test_results.csv
# 28       20250725T130821_ken3test_test_results.csv
# 29       20250725T130821_ken3test_test_results.csv
# 30  20250725T131157_mp2playertest_test_results.csv
# 31  20250725T131157_mp2playertest_test_results.csv
# 32  20250725T131157_mp2playertest_test_results.csv
# 33  20250725T131157_mp2playertest_test_results.csv
# 34  20250725T131157_mp2playertest_test_results.csv
# 35  20250725T131157_mp2playertest_test_results.csv
# 36  20250725T131157_mp2playertest_test_results.csv
# 37  20250725T131157_mp2playertest_test_results.csv
# 38  20250725T131157_mp2playertest_test_results.csv
# 39  20250725T131157_mp2playertest_test_results.csv
# 40  20250725T131157_mp2playertest_test_results.csv
# 41  20250725T131157_mp2playertest_test_results.csv
# 42  20250725T131157_mp2playertest_test_results.csv
# 43  20250725T131157_mp2playertest_test_results.csv
# 44  20250725T131157_mp2playertest_test_results.csv
# 45  20250725T131157_mp2playertest_test_results.csv
# 46  20250725T131157_mp2playertest_test_results.csv
# 47  20250725T131157_mp2playertest_test_results.csv
# 48  20250725T131157_mp2playertest_test_results.csv
# 49  20250725T131157_mp2playertest_test_results.csv

# %% [markdown]
# ## Saving this combined file to the Multiplayer test results folder:
# (This filename will consist of a condensed version of the earliest
# timestamp, followed by a 'CMR' string (which stands for 'combined
# multiplayer results), followed by tthe regular '_test_results.csv'
# suffix for test result files.)

# %%
df_combined_file_timestamp = df_combined.iloc[0]['Local_Test_Start_Time'][
0:19].replace('-', '').replace(':','') # This timestamp will also 
# get used as the argument for an upcoming run of the multiplayer 
# visualizations script.
df_combined_filename = df_combined_file_timestamp + '_CMR_test_results.csv'
df_combined_filename
# Out:
# '20250725T130325_CMR_test_results.csv'

# %%
df_combined_file_timestamp
# Out:
# '20250725T130325'

# %%
df_combined.to_csv('../Files/Multiplayer/'+df_combined_filename,
                  index = False)

# %%
print(f"Finished combining multiplayer files into a single file.\n This \
file is available at ../Files/Multiplayer/{df_combined_filename}.")
# Out:
# Finished combining multiplayer files into a single file.
#  This file is available at ../Files/Multiplayer/20250725T130325_CMR_test_results.csv.

# %% [markdown]
# ## Using the regular multiplayer analysis script to process these results:
#
# The following code is based on the example found at
# https://www.geeksforgeeks.org/python/how-to-run-another-python-script-with-arguments-in-python/ .

# %%
subprocess.run(['python', 'mp_visualizations.py', 
                df_combined_file_timestamp])
# Out:
# Finished calculating and visualizing multiplayer stats in 0.486 seconds.
# CompletedProcess(args=['python', 'mp_visualizations.py', '20250725T130325'], returncode=0)
